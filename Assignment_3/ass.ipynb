# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# -------------------------------
# Load MNIST Dataset
# -------------------------------
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize pixel values to [0,1]
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

# -------------------------------
# Hyperparameters to Compare
# -------------------------------
learning_rates = [0.0001, 0.001, 0.01]
epochs_list = [5, 10]

results = {}

# -------------------------------
# Train Model for Each Combination
# -------------------------------
for lr in learning_rates:
    for epochs in epochs_list:

        print(f"\n{'='*50}")
        print(f"Learning Rate: {lr} | Epochs: {epochs}")
        print(f"{'='*50}")

        # Build Neural Network
        model = Sequential([
            Flatten(input_shape=(28, 28)),
            Dense(128, activation='relu'),
            Dense(64, activation='relu'),
            Dense(10, activation='softmax')
        ])

        # Adam Optimizer
        optimizer = Adam(learning_rate=lr)

        # Compile Model
        model.compile(
            optimizer=optimizer,
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        # Train Model
        history = model.fit(
            X_train,
            y_train,
            epochs=epochs,
            batch_size=32,
            validation_split=0.2,
            verbose=1
        )

        # Evaluate Model
        test_loss, test_accuracy = model.evaluate(
            X_test,
            y_test,
            verbose=0
        )

        print(f"\nTest Loss     : {test_loss:.4f}")
        print(f"Test Accuracy : {test_accuracy*100:.2f}%")

        # Save Results
        results[(lr, epochs)] = {
            "accuracy": test_accuracy,
            "history": history
        }

        # Plot Accuracy
        plt.figure(figsize=(6,4))
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'LR={lr}, Epochs={epochs}')
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.legend()
        plt.grid(True)
        plt.show()

# -------------------------------
# Print Summary
# -------------------------------
print("\n")
print("="*40)
print("SUMMARY OF RESULTS")
print("="*40)

for (lr, epochs), value in results.items():
    print(f"Learning Rate = {lr:<7}  Epochs = {epochs:<2}  Accuracy = {value['accuracy']*100:.2f}%")
# Out:
# ==================================================
# Learning Rate: 0.0001 | Epochs: 5
# ==================================================
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/5
# c:\Users\shada\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8421 - loss: 0.6115 - val_accuracy: 0.9178 - val_loss: 0.2965
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9237 - loss: 0.2692 - val_accuracy: 0.9362 - val_loss: 0.2271
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9388 - loss: 0.2145 - val_accuracy: 0.9457 - val_loss: 0.1952
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9480 - loss: 0.1806 - val_accuracy: 0.9538 - val_loss: 0.1697
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9552 - loss: 0.1565 - val_accuracy: 0.9574 - val_loss: 0.1530
#
# Test Loss     : 0.1494
# Test Accuracy : 95.63%
# ==================================================
# Learning Rate: 0.0001 | Epochs: 10
# ==================================================
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8286 - loss: 0.6497 - val_accuracy: 0.9216 - val_loss: 0.2867
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9252 - loss: 0.2657 - val_accuracy: 0.9405 - val_loss: 0.2194
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9396 - loss: 0.2117 - val_accuracy: 0.9480 - val_loss: 0.1892
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9480 - loss: 0.1802 - val_accuracy: 0.9532 - val_loss: 0.1700
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9551 - loss: 0.1578 - val_accuracy: 0.9565 - val_loss: 0.1540
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9610 - loss: 0.1399 - val_accuracy: 0.9583 - val_loss: 0.1458
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9642 - loss: 0.1257 - val_accuracy: 0.9622 - val_loss: 0.1364
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9679 - loss: 0.1138 - val_accuracy: 0.9641 - val_loss: 0.1293
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9713 - loss: 0.1034 - val_accuracy: 0.9657 - val_loss: 0.1216
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9736 - loss: 0.0943 - val_accuracy: 0.9682 - val_loss: 0.1163
#
# Test Loss     : 0.1096
# Test Accuracy : 96.78%
# ==================================================
# Learning Rate: 0.001 | Epochs: 5
# ==================================================
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9225 - loss: 0.2669 - val_accuracy: 0.9614 - val_loss: 0.1285
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.